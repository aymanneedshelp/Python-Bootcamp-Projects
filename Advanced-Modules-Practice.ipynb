# %% [markdown]
# We have to unzip 'unzip_me_for_instructions.zip' in order to get the instructions

# %%
import shutil
shutil.unpack_archive('unzip_me_for_instructions.zip','instructions','zip')

# %% [markdown]
# ![Screenshot%202021-06-09%20at%2010.14.51%20AM.png](attachment:Screenshot%202021-06-09%20at%2010.14.51%20AM.png)

# %% [markdown]
# Good work on unzipping the file!
#
# You should now see 5 folders, each with a lot of random .txt files.
#
# Within one of these text files is a telephone number formated ###-###-####
#
# Use the Python os module and regular expressions to iterate through each file, open it, and search for a telephone number.
#
# Good luck!

# %%
pwd
# Out:
# '/Users/ayman/Documents/Coding/PracticeStuff/Udemy Course stuff/Advanced-Modules-Practice'

# %%
pattern = re.compile(r"(\d{3})-(\d{3})-(\d{4})")
file_dir = '/Users/ayman/Documents/Coding/PracticeStuff/Udemy Course stuff/Advanced-Modules-Practice/instructions/extracted_content'

found = False

for folder, sub_folders, files in os.walk(file_dir):
    for file in files:
        path = folder+'/'+file
        with open(path,'r') as f:
            text = f.read()
        result = re.search(pattern,text)
        if result != None:
            span = result.span()
            number = result.group()
            print(f"Phone number {number} has been found")
            print(f"Folder: {folder}")
            print(f"File name: {file}")
            print(f'Span: {span}')
# Out:
# Phone number 719-266-2837 has been found
# Folder: /Users/ayman/Documents/Coding/PracticeStuff/Udemy Course stuff/Advanced-Modules-Practice/instructions/extracted_content/Four
# File name: EMTGPSXQEJX.txt
# Span: (1062, 1074)
